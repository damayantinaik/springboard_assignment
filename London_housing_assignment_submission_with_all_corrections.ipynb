# %% [markdown]
# # Springboard Data Science Career Track Unit 4 Challenge - Tier 3 Complete
#
# ## Objectives
# Hey! Great job getting through those challenging DataCamp courses. You're learning a lot in a short span of time.
#
# In this notebook, you're going to apply the skills you've been learning, bridging the gap between the controlled environment of DataCamp and the *slightly* messier work that data scientists do with actual datasets!
#
# Here’s the mystery we’re going to solve: ***which boroughs of London have seen the greatest increase in housing prices, on average, over the last two decades?***
#
#
# A borough is just a fancy word for district. You may be familiar with the five boroughs of New York… well, there are 32 boroughs within Greater London [(here's some info for the curious)](https://en.wikipedia.org/wiki/London_boroughs). Some of them are more desirable areas to live in, and the data will reflect that with a greater rise in housing prices.
#
# ***This is the Tier 3 notebook, which means it's not filled in at all: we'll just give you the skeleton of a project, the brief and the data. It's up to you to play around with it and see what you can find out! Good luck! If you struggle, feel free to look at easier tiers for help; but try to dip in and out of them, as the more independent work you do, the better it is for your learning!***
#
# This challenge will make use of only what you learned in the following DataCamp courses:
# - Prework courses (Introduction to Python for Data Science, Intermediate Python for Data Science)
# - Data Types for Data Science
# - Python Data Science Toolbox (Part One)
# - pandas Foundations
# - Manipulating DataFrames with pandas
# - Merging DataFrames with pandas
#
# Of the tools, techniques and concepts in the above DataCamp courses, this challenge should require the application of the following:
# - **pandas**
#     - **data ingestion and inspection** (pandas Foundations, Module One)
#     - **exploratory data analysis** (pandas Foundations, Module Two)
#     - **tidying and cleaning** (Manipulating DataFrames with pandas, Module Three)
#     - **transforming DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **subsetting DataFrames with lists** (Manipulating DataFrames with pandas, Module One)
#     - **filtering DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **grouping data** (Manipulating DataFrames with pandas, Module Four)
#     - **melting data** (Manipulating DataFrames with pandas, Module Three)
#     - **advanced indexing** (Manipulating DataFrames with pandas, Module Four)
# - **matplotlib** (Intermediate Python for Data Science, Module One)
# - **fundamental data types** (Data Types for Data Science, Module One)
# - **dictionaries** (Intermediate Python for Data Science, Module Two)
# - **handling dates and times** (Data Types for Data Science, Module Four)
# - **function definition** (Python Data Science Toolbox - Part One, Module One)
# - **default arguments, variable length, and scope** (Python Data Science Toolbox - Part One, Module Two)
# - **lambda functions and error handling** (Python Data Science Toolbox - Part One, Module Four)

# %% [markdown]
# ## The Data Science Pipeline
#
# This is Tier Three, so we'll get you started. But after that, it's all in your hands! When you feel done with your investigations, look back over what you've accomplished, and prepare a quick presentation of your findings for the next mentor meeting.
#
# Data Science is magical. In this case study, you'll get to apply some complex machine learning algorithms. But as  [David Spiegelhalter](https://www.youtube.com/watch?v=oUs1uvsz0Ok) reminds us, there is no substitute for simply **taking a really, really good look at the data.** Sometimes, this is all we need to answer our question.
#
# Data Science projects generally adhere to the four stages of Data Science Pipeline:
# 1. Sourcing and loading
# 2. Cleaning, transforming, and visualizing
# 3. Modeling
# 4. Evaluating and concluding

# %% [markdown]
# ### 1. Sourcing and Loading
#
# Any Data Science project kicks off by importing  ***pandas***. The documentation of this wonderful library can be found [here](https://pandas.pydata.org/). As you've seen, pandas is conveniently connected to the [Numpy](http://www.numpy.org/) and [Matplotlib](https://matplotlib.org/) libraries.
#
# ***Hint:*** This part of the data science pipeline will test those skills you acquired in the pandas Foundations course, Module One.

# %% [markdown]
# #### 1.1. Importing Libraries

# %%
# Let's import the pandas, numpy libraries as pd, and np respectively. 
import pandas as pd
import numpy as np

# Load the pyplot collection of functions from matplotlib, as plt 
import matplotlib.pyplot as plt

# %% [markdown]
# #### 1.2.  Loading the data
# Your data comes from the [London Datastore](https://data.london.gov.uk/): a free, open-source data-sharing portal for London-oriented datasets.

# %%
# First, make a variable called url_LondonHousePrices, and assign it the following link, enclosed in quotation-marks as a string:
# https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls

url_LondonHousePrices = "https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls"

# The dataset we're interested in contains the Average prices of the houses, and is actually on a particular sheet of the Excel file. 
# As a result, we need to specify the sheet name in the read_excel() method.
# Put this data into a variable called properties.  
properties = pd.read_excel(url_LondonHousePrices, sheet_name='Average price', index_col= None)

# %% [markdown]
# ### 2. Cleaning, transforming, and visualizing
# This second stage is arguably the most important part of any Data Science project. The first thing to do is take a proper look at the data. Cleaning forms the majority of this stage, and can be done both before or after Transformation.
#
# The end goal of data cleaning is to have tidy data. When data is tidy:
#
# 1. Each variable has a column.
# 2. Each observation forms a row.
#
# Keep the end goal in mind as you move through this process, every step will take you closer.
#
#
#
# ***Hint:*** This part of the data science pipeline should test those skills you acquired in:
# - Intermediate Python for data science, all modules.
# - pandas Foundations, all modules.
# - Manipulating DataFrames with pandas, all modules.
# - Data Types for Data Science, Module Four.
# - Python Data Science Toolbox - Part One, all modules

# %% [markdown]
# **2.1. Exploring your data**
#
# Think about your pandas functions for checking out a dataframe.

# %%
properties.head()
# Out:
#   Unnamed: 0 City of London Barking & Dagenham     Barnet     Bexley  \
# 0        NaT      E09000001          E09000002  E09000003  E09000004
# 1 1995-01-01          91449            50460.2    93284.5    64958.1
# 2 1995-02-01        82202.8            51085.8    93190.2    64787.9
# 3 1995-03-01        79120.7              51269    92247.5    64367.5
# 4 1995-04-01        77101.2            53133.5    90762.9    64277.7
#
#        Brent    Bromley     Camden    Croydon     Ealing  ... NORTH WEST  \
# 0  E09000005  E09000006  E09000007  E09000008  E09000009  ...  E12000002
# 1    71306.6    81671.5     120933    69158.2    79885.9  ...    43958.5
# 2    72022.3    81657.6     119509    68951.1    80897.1  ...    43925.4
# 3    72015.8    81449.3     120282    68712.4    81379.9  ...    44434.9
# 4    72965.6    81124.4     120098      68610    82188.9  ...    44267.8
#
#   YORKS & THE HUMBER EAST MIDLANDS WEST MIDLANDS EAST OF ENGLAND     LONDON  \
# 0          E12000003     E12000004     E12000005       E12000006  E12000007
# 1            44803.4       45544.5       48527.5         56701.6    74435.8
# 2            44528.8       46051.6       49341.3         56593.6    72777.9
# 3            45200.5       45383.8       49442.2         56171.2    73896.8
# 4            45614.3       46124.2       49455.9         56567.9    74455.3
#
#   SOUTH EAST SOUTH WEST Unnamed: 47    England
# 0  E12000008  E12000009         NaN  E92000001
# 1    64018.9    54705.2         NaN    53202.8
# 2      63715    54356.1         NaN    53096.2
# 3    64113.6    53583.1         NaN    53201.3
# 4    64623.2      54786         NaN    53590.9
#
# [5 rows x 49 columns]

# %%
properties.shape
# Out:
# (313, 49)

# %%
properties.describe()
# Out:
#        Unnamed: 34  Unnamed: 37  Unnamed: 47
# count          0.0          0.0          0.0
# mean           NaN          NaN          NaN
# std            NaN          NaN          NaN
# min            NaN          NaN          NaN
# 25%            NaN          NaN          NaN
# 50%            NaN          NaN          NaN
# 75%            NaN          NaN          NaN
# max            NaN          NaN          NaN

# %%
properties.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 313 entries, 0 to 312
# Data columns (total 49 columns):
# Unnamed: 0              312 non-null datetime64[ns]
# City of London          313 non-null object
# Barking & Dagenham      313 non-null object
# Barnet                  313 non-null object
# Bexley                  313 non-null object
# Brent                   313 non-null object
# Bromley                 313 non-null object
# Camden                  313 non-null object
# Croydon                 313 non-null object
# Ealing                  313 non-null object
# Enfield                 313 non-null object
# Greenwich               313 non-null object
# Hackney                 313 non-null object
# Hammersmith & Fulham    313 non-null object
# Haringey                313 non-null object
# Harrow                  313 non-null object
# Havering                313 non-null object
# Hillingdon              313 non-null object
# Hounslow                313 non-null object
# Islington               313 non-null object
# Kensington & Chelsea    313 non-null object
# Kingston upon Thames    313 non-null object
# Lambeth                 313 non-null object
# Lewisham                313 non-null object
# Merton                  313 non-null object
# Newham                  313 non-null object
# Redbridge               313 non-null object
# Richmond upon Thames    313 non-null object
# Southwark               313 non-null object
# Sutton                  313 non-null object
# Tower Hamlets           313 non-null object
# Waltham Forest          313 non-null object
# Wandsworth              313 non-null object
# Westminster             313 non-null object
# Unnamed: 34             0 non-null float64
# Inner London            313 non-null object
# Outer London            313 non-null object
# Unnamed: 37             0 non-null float64
# NORTH EAST              313 non-null object
# NORTH WEST              313 non-null object
# YORKS & THE HUMBER      313 non-null object
# EAST MIDLANDS           313 non-null object
# WEST MIDLANDS           313 non-null object
# EAST OF ENGLAND         313 non-null object
# LONDON                  313 non-null object
# SOUTH EAST              313 non-null object
# SOUTH WEST              313 non-null object
# Unnamed: 47             0 non-null float64
# England                 313 non-null object
# dtypes: datetime64[ns](1), float64(3), object(45)
# memory usage: 119.9+ KB

# %%
properties.dtypes
# Out:
# Unnamed: 0              datetime64[ns]
# City of London                  object
# Barking & Dagenham              object
# Barnet                          object
# Bexley                          object
# Brent                           object
# Bromley                         object
# Camden                          object
# Croydon                         object
# Ealing                          object
# Enfield                         object
# Greenwich                       object
# Hackney                         object
# Hammersmith & Fulham            object
# Haringey                        object
# Harrow                          object
# Havering                        object
# Hillingdon                      object
# Hounslow                        object
# Islington                       object
# Kensington & Chelsea            object
# Kingston upon Thames            object
# Lambeth                         object
# Lewisham                        object
# Merton                          object
# Newham                          object
# Redbridge                       object
# Richmond upon Thames            object
# Southwark                       object
# Sutton                          object
# Tower Hamlets                   object
# Waltham Forest                  object
# Wandsworth                      object
# Westminster                     object
# Unnamed: 34                    float64
# Inner London                    object
# Outer London                    object
# Unnamed: 37                    float64
# NORTH EAST                      object
# NORTH WEST                      object
# YORKS & THE HUMBER              object
# EAST MIDLANDS                   object
# WEST MIDLANDS                   object
# EAST OF ENGLAND                 object
# LONDON                          object
# SOUTH EAST                      object
# SOUTH WEST                      object
# Unnamed: 47                    float64
# England                         object
# dtype: object

# %%
properties.head(5)
# Out:
#   Unnamed: 0 City of London Barking & Dagenham     Barnet     Bexley  \
# 0        NaT      E09000001          E09000002  E09000003  E09000004
# 1 1995-01-01          91449            50460.2    93284.5    64958.1
# 2 1995-02-01        82202.8            51085.8    93190.2    64787.9
# 3 1995-03-01        79120.7              51269    92247.5    64367.5
# 4 1995-04-01        77101.2            53133.5    90762.9    64277.7
#
#        Brent    Bromley     Camden    Croydon     Ealing  ... NORTH WEST  \
# 0  E09000005  E09000006  E09000007  E09000008  E09000009  ...  E12000002
# 1    71306.6    81671.5     120933    69158.2    79885.9  ...    43958.5
# 2    72022.3    81657.6     119509    68951.1    80897.1  ...    43925.4
# 3    72015.8    81449.3     120282    68712.4    81379.9  ...    44434.9
# 4    72965.6    81124.4     120098      68610    82188.9  ...    44267.8
#
#   YORKS & THE HUMBER EAST MIDLANDS WEST MIDLANDS EAST OF ENGLAND     LONDON  \
# 0          E12000003     E12000004     E12000005       E12000006  E12000007
# 1            44803.4       45544.5       48527.5         56701.6    74435.8
# 2            44528.8       46051.6       49341.3         56593.6    72777.9
# 3            45200.5       45383.8       49442.2         56171.2    73896.8
# 4            45614.3       46124.2       49455.9         56567.9    74455.3
#
#   SOUTH EAST SOUTH WEST Unnamed: 47    England
# 0  E12000008  E12000009         NaN  E92000001
# 1    64018.9    54705.2         NaN    53202.8
# 2      63715    54356.1         NaN    53096.2
# 3    64113.6    53583.1         NaN    53201.3
# 4    64623.2      54786         NaN    53590.9
#
# [5 rows x 49 columns]

# %% [markdown]
# **2.2. Cleaning the data**
#
# You might find you need to transpose your dataframe, check out what its row indexes are, and reset the index. You  also might find you need to assign the values of the first row to your column headings  . (Hint: recall the .columns feature of DataFrames, as well as the iloc[] method).
#
# Don't be afraid to use StackOverflow for help  with this.

# %%
properties_T  = properties.T
properties_T
# Out:
#                             0                    1                    2    \
# Unnamed: 0                  NaT  1995-01-01 00:00:00  1995-02-01 00:00:00
# City of London        E09000
# Unnamed: 37                           NaN                  NaN
# NORTH EAST                        43287.7              41899.1
# NORTH WEST                        44109.6              44193.7
# YORKS & THE HUMBER                  45535              45111.5
# EAST MIDLANDS                     46037.7              45922.5
# WEST MIDLANDS                       49860              49598.5
# EAST OF ENGLAND                   57242.3              56732.4
# LONDON                            75984.2              75529.3
# SOUTH EAST                        65224.9              64851.6
# SOUTH WEST                        54265.9              54365.7
# Unnamed: 47                           NaN                  NaN
# England                           53900.6              53600.3
#
#                                       9    ...                  303  \
# Unnamed: 0            1995-09-01 00:00:00  ...  2020-03-01 00:00:00
# City of London                     104473  ...               836241
# Barking & Dagenham                51471.6  ...               301413
# Barnet                            93273.1  ...               522115
# Bexley                            64509.5  ...               339182
# Brent                             73789.5  ...               466250
# Bromley                           81440.4  ...               432310
# Camden                             120597  ...               854443
# Croydon                           69393.5  ...               371007
# Ealing                            82011.1  ...               480330
# Enfield                           71725.2  ...               392339
# Greenwich                         63996.8  ...               394446
# Hackney                           68752.5  ...               578130
# Hammersmith & Fulham               123094  ...               717721
# Haringey                          82142.9  ...               543929
# Harrow                              83607  ...               450484
# Havering                          68108.2  ...               365418
# Hillingdon                        73843.6  ...               409234
# Hounslow                          74426.7  ...               409444
# Islington                         99582.6  ...               651932
# Kensington & Chelsea               197048  ...          1.34412e+06
# Kingston upon Thames                85111  ...               486392
# Lambeth                           70155.8  ...               514006
# Lewisham                            58743  ...               412505
# Merton                            80824.7  ...               513961
# Newham                            54585.5  ...               366990
# Redbridge                           73204  ...               420539
# Richmond upon Thames               110425  ...               654949
# Southwark                           63467  ...               496620
# Sutton                            69937.4  ...               375195
# Tower Hamlets                     62177.6  ...               480145
# Waltham Forest                    61548.2  ...               436487
# Wandsworth                        91373.7  ...               609325
# Westminster                        135993  ...          1.00666e+06
# Unnamed: 34                           NaN  ...                  NaN
# Inner London                      80402.9  ...               583041
# Outer London                      73454.4  ...               425232
# Unnamed: 37                           NaN  ...                  NaN
# NORTH EAST                        41850.9  ...               128335
# NORTH WEST                        44088.1  ...               166676
# YORKS & THE HUMBER                44837.9  ...               165486
# EAST MIDLANDS                     45771.7  ...               196012
# WEST MIDLANDS                     49319.7  ...               199894
# EAST OF ENGLAND                   56259.3  ...               288815
# LONDON                            74940.8  ...               482523
# SOUTH EAST                        64352.5  ...               323681
# SOUTH WEST                          54244  ...               259746
# Unnamed: 47                           NaN  ...                  NaN
# England                           53309.2  ...               249403
#
#                                       304                  305  \
# Unnamed: 0            2020-04-01 00:00:00  2020-05-01 00:00:00
# City of London                     920444               918209
# Barking & Dagenham                 293603               293816
# Barnet                             526689               526033
# Bexley                             341553               339353
# Brent                              470601               482808
# Bromley                            433426               425300
# Camden                             862077               855338
# Croydon                            370032               373805
# Ealing                             480314               473283
# Enfield                            395240               391460
# Greenwich                          395917               392507
# Hackney                            579285               576964
# Hammersmith & Fulham               698951               680111
# Haringey                           544722               549865
# Harrow                             451482               445417
# Havering                           369485               367940
# Hillingdon                         403517               407142
# Hounslow                           401334               396578
# Islington                          642190               630653
# Richmond upon Thames               709148
# Southwark                          519142
# Sutton                             398639
# Tower Hamlets                      471445
# Waltham Forest                     485676
# Wandsworth                         618531
# Westminster                        930070
# Unnamed: 34                           NaN
# Inner London                       594749
# Outer London                       447187
# Unnamed: 37                           NaN
# NORTH EAST                         141154
# NORTH WEST                         183727
# YORKS & THE HUMBER                 182907
# EAST MIDLANDS                      215046
# WEST MIDLANDS                      216950
# EAST OF ENGLAND                    310912
# LONDON                             496066
# SOUTH EAST                         341007
# SOUTH WEST                         282388
# Unnamed: 47                           NaN
# England                            269150
#
# [49 rows x 313 columns]

# %%
properties_T.shape
# Out:
# (49, 313)

# %%
properties_T.index
# Out:
# Index(['Unnamed: 0', 'City of London', 'Barking & Dagenham', 'Barnet',
#        'Bexley', 'Brent', 'Bromley', 'Camden', 'Croydon', 'Ealing', 'Enfield',
#        'Greenwich', 'Hackney', 'Hammersmith & Fulham', 'Haringey', 'Harrow',
#        'Havering', 'Hillingdon', 'Hounslow', 'Islington',
#        'Kensington & Chelsea', 'Kingston upon Thames', 'Lambeth', 'Lewisham',
#        'Merton', 'Newham', 'Redbridge', 'Richmond upon Thames', 'Southwark',
#        'Sutton', 'Tower Hamlets', 'Waltham Forest', 'Wandsworth',
#        'Westminster', 'Unnamed: 34', 'Inner London', 'Outer London',
#        'Unnamed: 37', 'NORTH EAST', 'NORTH WEST', 'YORKS & THE HUMBER',
#        'EAST MIDLANDS', 'WEST MIDLANDS', 'EAST OF ENGLAND', 'LONDON',
#        'SOUTH EAST', 'SOUTH WEST', 'Unnamed: 47', 'England'],
#       dtype='object')

# %%
properties_T.columns
# Out:
# RangeIndex(start=0, stop=313, step=1)

# %%
# Let us check the 1st column, which seems different from the price
properties_T[0]
# Out:
# Unnamed: 0                    NaT
# City of London          E09000001
# Barking & Dagenham      E09000002
# Barnet                  E09000003
# Bexley                  E09000004
# Brent                   E09000005
# Bromley                 E09000006
# Camden                  E09000007
# Croydon                 E09000008
# Ealing                  E09000009
# Enfield                 E09000010
# Greenwich               E09000011
# Hackney                 E09000012
# Hammersmith & Fulham    E09000013
# Haringey                E09000014
# Harrow                  E09000015
# Havering                E09000016
# Hillingdon              E09000017
# Hounslow                E09000018
# Islington               E09000019
# Kensington & Chelsea    E09000020
# Kingston upon Thames    E09000021
# Lambeth                 E09000022
# Lewisham                E09000023
# Merton                  E09000024
# Newham                  E09000025
# Redbridge               E09000026
# Richmond upon Thames    E09000027
# Southwark               E09000028
# Sutton                  E09000029
# Tower Hamlets           E09000030
# Waltham Forest          E09000031
# Wandsworth              E09000032
# Westminster             E09000033
# Unnamed: 34                   NaN
# Inner London            E13000001
# Outer London            E13000002
# Unnamed: 37                   NaN
# NORTH EAST              E12000001
# NORTH WEST              E12000002
# YORKS & THE HUMBER      E12000003
# EAST MIDLANDS           E12000004
# WEST MIDLANDS           E12000005
# EAST OF ENGLAND         E12000006
# LONDON                  E12000007
# SOUTH EAST              E12000008
# SOUTH WEST              E12000009
# Unnamed: 47                   NaN
# England                 E92000001
# Name: 0, dtype: object

# %%
# Drop the 1st columns as it is some reference number for each borough
properties_T_no_reference_column = properties_T.drop(0, axis = 1)
properties_T_no_reference_column
# Out:
#                                       1                    2    \
# Unnamed: 0            1995-01-01 00:00:00  1995-02-01 00:00:00
# City of London                      91449              82202.8
# Barking & Dagenham                50460.2              51085.8
# Barnet                            93284.5              93190.2
# Bexley                            64958.1              64787.9
# Brent                             71306.6              72022.3
# Bromley                           81671.5              81657.6
# Camden                             120933               119509
# Croydon                           69158.2              68951.1
# Ealing                            79885.9              80897.1
# Enfield                           72514.7              73155.2
# Greenwich                         62300.1              60993.3
# Hackney                           61296.5              63187.1
# Hammersmith & Fulham               124903               122088
# Haringey                          76287.6              78901.2
# Harrow                            84769.5              83396.1
# Havering                          68000.1              69393.5
# Hillingdon                        73834.8              75031.1
# Hounslow                          72231.7              71051.6
# Islington                         92516.5              94342.4
# Kensington & Chelsea               182695               182345
# Kingston upon Thames              80875.8              81230.1
# Harrow                            83853.7              84173.2
# Havering                          68534.5              68464.6
# Hillingdon                        73117.1                74005
# Hounslow                          72877.5              72331.1
# Islington                         94346.4              97428.9
# Kensington & Chelsea               191474               197266
# Kingston upon Thames              82123.5              82205.7
# Lambeth                           69035.1              68881.2
# Lewisham                          58551.4              58041.4
# Merton                              80874              80704.9
# Newham                              55804              56067.8
# Redbridge                         72366.6              72279.4
# Richmond upon Thames               107708               112865
# Southwark                         64420.5              64155.8
# Sutton                            69759.2              70125.2
# Tower Hamlets                     66432.9              66232.2
# Waltham Forest                    61494.2              61547.8
# Wandsworth                        86518.1              88114.3
# Westminster                        133911               134562
# Unnamed: 34                           NaN                  NaN
# Inner London                      79129.2              79969.2
# Outer London                        72753              73189.4
# Unnamed: 37                           NaN                  NaN
# NORTH EAST                        43266.5              42315.3
# NORTH WEST                        44223.6                44113
# YORKS & THE HUMBER                  44831              45392.6
# EAST MIDLANDS                       45878                45680
# WEST MIDLANDS                     50369.7              50100.4
# EAST OF ENGLAND                   56479.8              56288.9
# LONDON                              75432              75606.2
# SOUTH EAST                        64530.4                65511
# SOUTH WEST                        54698.8              54420.2
# Unnamed: 47                           NaN                  NaN
# England                           53678.2              53735.2
#
#                                       7                    8    \
# Unnamed: 0            1995-07-01 00:00:00  1995-08-01 00:00:00
# City of London                     110128               112329
# Barking & Dagenham                52113.1              52232.2
# Barnet                            91441.2              92361.3
# Bexley                            63722.7              64432.6
# Brent                               74127                73547
# Bromley                           82898.5              82054.4
# Camden                             124028               125530
# Croydon                           69142.5              68993.4
# Ealing                            82352.2              82706.7
# Enfield                           71837.5              72237.9
# Greenwich                         65486.3              65076.4
# Hackney                           68390.8              68096.8
# Hammersmith & Fulham               124382               123625
# Haringey                          80746.3              81217.7
# Harrow                            84226.7              84430.6
# Havering                          68680.8              69023.4
# Hillingdon                        74671.1              74967.9
# Hounslow                          73717.8              74479.9
# Islington                         98976.1              98951.2
# Kensington & Chelsea               197963               198037
# Kingston upon Thames              82525.8              83342.8
# Lambeth                           69608.7                68840
# Lewisham                          58126.4              58151.3
# Merton                            81055.9              80781.1
# Newham                            55458.3              54709.4
# Redbridge                         72880.8              73275.2
# Richmond upon Thames               114657               112320
# Southwark                         67024.7              65525.9
# Sutton                            70789.6              69958.4
# Tower Hamlets                     64692.2              63472.3
# Waltham Forest                    61933.5              61916.4
# Wandsworth                        89830.6              90560.7
# Westminster                        133450               136582
# Unnamed: 34                           NaN                  NaN
# Inner London                      80550.5              80597.6
# Outer London                      73665.9              73691.1
# Unnamed: 37                           NaN                  NaN
# NORTH EAST                        43287.7              41899.1
# NORTH WEST                        44109.6              44193.7
# YORKS & THE HUMBER                  45535              45111.5
# EAST MIDLANDS                     46037.7              45922.5
# WEST MIDLANDS                       49860              49598.5
# EAST OF ENGLAND                   57242.3              56732.4
# LONDON                            75984.2              75529.3
# SOUTH EAST                        65224.9              64851.6
# SOUTH WEST                        54265.9              54365.7
# Unnamed: 47                           NaN                  NaN
# England                           53900.6              53600.3
#
#                                       9                    10   ...  \
# Unnamed: 0            1995-09-01 00:00:00  1995-10-01 00:00:00  ...
# City of London                     104473               108038  ...
# Barking & Dagenham                51471.6              51513.8  ...
# Barnet                            93273.1              92567.4  ...
# Bexley                            64509.5              64529.9  ...
# Brent                             73789.5              73264.1  ...
# Bromley                           81440.4              81862.2  ...
# Camden                             120597               117458  ...
# Croydon                           69393.5              68934.6  ...
# Ealing                            82011.1              80522.7  ...
# Enfield                           71725.2              72349.1  ...
# Greenwich                         63996.8              63405.3  ...
# Hackney                           68752.5              67619.7  ...
# Hammersmith & Fulham               123094               123443  ...
# Haringey                          82142.9              81791.5  ...
# Harrow                              83607              82492.7  ...
# Havering                          68108.2              67425.6  ...
# Hillingdon                        73843.6              72992.5  ...
# Hounslow                          74426.7              73643.1  ...
# Islington                         99582.6              97580.4  ...
# Kensington & Chelsea               197048               200006  ...
# Kingston upon Thames                85111                85727  ...
# Lambeth                           70155.8              69616.2  ...
# Lewisham                            58743              58073.1  ...
# Merton                            80824.7              79569.2  ...
# Newham                            54585.5              54789.6  ...
# Redbridge                           73204              72917.5  ...
# Richmond upon Thames               110425               108407  ...
# Southwark                           63467                60886  ...
# Sutton                            69937.4              69963.8  ...
# Tower Hamlets                     62177.6              62066.5  ...
# Waltham Forest                    61548.2              60572.6  ...
# Wandsworth                        91373.7              90246.4  ...
# Westminster                        135993               134513  ...
# Unnamed: 34                           NaN                  NaN  ...
# Inner London                      80402.9              79681.5  ...
# Outer London                      73454.4              72971.6  ...
# Unnamed: 37                           NaN                  NaN  ...
# NORTH EAST                        41850.9              41688.2  ...
# NORTH WEST                        44088.1                43110  ...
# YORKS & THE HUMBER                44837.9                44310  ...
# EAST MIDLANDS                     45771.7              45154.7  ...
# WEST MIDLANDS                     49319.7              49597.9  ...
# EAST OF ENGLAND                   56259.3              55240.3  ...
# LONDON                            74940.8              74302.1  ...
# SOUTH EAST                        64352.5              64125.8  ...
# SOUTH WEST                          54244              54264.6  ...
# Unnamed: 47                           NaN                  NaN  ...
# England                           53309.2              52844.6  ...
#
#                                       303                  304  \
# Unnamed: 0            2020-03-01 00:00:00  2020-04-01 00:00:00
# City of London                     836241               920444
# Barking & Dagenham                 301413               293603
# Barnet                             522115               526689
# Bexley                             339182               341553
# Brent                              466250               470601
# Bromley                            432310               433426
# Camden                             854443               862077
# Croydon                            371007               370032
# Ealing                             480330               480314
# Enfield                            392339               395240
# Greenwich                          394446               395917
# Hackney                            578130               579285
# Hammersmith & Fulham               717721               698951
# Haringey                           543929               544722
# Harrow                             450484               451482
# Havering                           365418               369485
# Hillingdon                         409234               403517
# Hounslow                           409444               401334
# Islington                          651932               642190
# Kensington & Chelsea          1.34412e+06          1.36651e+06
# Kingston upon Thames               486392               486367
# Lambeth                            514006               503116
# Lewisham                           412505               412995
# Merton                             513961               511327
# Newham                             366990               360609
# Redbridge                          420539               419057
# Richmond upon Thames               654949               665144
# Southwark                          496620               500245
# Sutton                             375195               376824
# Tower Hamlets                      480145               470444
# Waltham Forest                     436487               440821
# Wandsworth                         609325               612598
# Westminster                   1.00666e+06          1.02679e+06
# Unnamed: 34                           NaN                  NaN
# Inner London                       583041               581017
# Outer London                       425232               425810
# Unnamed: 37                           NaN                  NaN
# NORTH EAST                
# Unnamed: 37                           NaN                  NaN
# NORTH EAST                         138460               141154
# NORTH WEST                         179328               183727
# YORKS & THE HUMBER                 180836               182907
# EAST MIDLANDS                      209283               215046
# WEST MIDLANDS                      212822               216950
# EAST OF ENGLAND                    303748               310912
# LONDON                             501488               496066
# SOUTH EAST                         340638               341007
# SOUTH WEST                         276115               282388
# Unnamed: 47                           NaN                  NaN
# England                            265268               269150
#
# [49 rows x 312 columns]

# %%
properties2 = properties_T_no_reference_column.T
properties2.head()
# Out:
#   Unnamed: 0 City of London Barking & Dagenham   Barnet   Bexley    Brent  \
# 1 1995-01-01          91449            50460.2  93284.5  64958.1  71306.6
# 2 1995-02-01        82202.8            51085.8  93190.2  64787.9  72022.3
# 3 1995-03-01        79120.7              51269  92247.5  64367.5  72015.8
# 4 1995-04-01        77101.2            53133.5  90762.9  64277.7  72965.6
# 5 1995-05-01        84409.1            53042.2    90258  63997.1    73704
#
#    Bromley  Camden  Croydon   Ealing  ... NORTH WEST YORKS & THE HUMBER  \
# 1  81671.5  120933  69158.2  79885.9  ...    43958.5            44803.4
# 2  81657.6  119509  68951.1  80897.1  ...    43925.4            44528.8
# 3  81449.3  120282  68712.4  81379.9  ...    44434.9            45200.5
# 4  81124.4  120098    68610  82188.9  ...    44267.8            45614.3
# 5  81542.6  119929  68844.9  82077.1  ...    44223.6              44831
#
#   EAST MIDLANDS WEST MIDLANDS EAST OF ENGLAND   LONDON SOUTH EAST SOUTH WEST  \
# 1       45544.5       48527.5         56701.6  74435.8    64018.9    54705.2
# 2       46051.6       49341.3         56593.6  72777.9      63715    54356.1
# 3       45383.8       49442.2         56171.2  73896.8    64113.6    53583.1
# 4       46124.2       49455.9         56567.9  74455.3    64623.2      54786
# 5         45878       50369.7         56479.8    75432    64530.4    54698.8
#
#   Unnamed: 47  England
# 1         NaN  53202.8
# 2         NaN  53096.2
# 3         NaN  53201.3
# 4         NaN  53590.9
# 5         NaN  53678.2
#
# [5 rows x 49 columns]

# %%
properties3 = properties2.set_index('Unnamed: 0')
properties3.head()
# Out:
#            City of London Barking & Dagenham   Barnet   Bexley    Brent  \
# Unnamed: 0
# 1995-01-01          91449            50460.2  93284.5  64958.1  71306.6
# 1995-02-01        82202.8            51085.8  93190.2  64787.9  72022.3
# 1995-03-01        79120.7              51269  92247.5  64367.5  72015.8
# 1995-04-01        77101.2            53133.5  90762.9  64277.7  72965.6
# 1995-05-01        84409.1            53042.2    90258  63997.1    73704
#
#             Bromley  Camden  Croydon   Ealing  Enfield  ... NORTH WEST  \
# Unnamed: 0                                              ...
# 1995-01-01  81671.5  120933  69158.2  79885.9  72514.7  ...    43958.5
# 1995-02-01  81657.6  119509  68951.1  80897.1  73155.2  ...    43925.4
# 1995-03-01  81449.3  120282  68712.4  81379.9  72190.4  ...    44434.9
# 1995-04-01  81124.4  120098    68610  82188.9  71442.9  ...    44267.8
# 1995-05-01  81542.6  119929  68844.9  82077.1  70630.8  ...    44223.6
#
#            YORKS & THE HUMBER EAST MIDLANDS WEST MIDLANDS EAST OF ENGLAND  \
# Unnamed: 0
# 1995-01-01            44803.4       45544.5       48527.5         56701.6
# 1995-02-01            44528.8       46051.6       49341.3         56593.6
# 1995-03-01            45200.5       45383.8       49442.2         56171.2
# 1995-04-01            45614.3       46124.2       49455.9         56567.9
# 1995-05-01              44831         45878       50369.7         56479.8
#
#              LONDON SOUTH EAST SOUTH WEST Unnamed: 47  England
# Unnamed: 0
# 1995-01-01  74435.8    64018.9    54705.2         NaN  53202.8
# 1995-02-01  72777.9      63715    54356.1         NaN  53096.2
# 1995-03-01  73896.8    64113.6    53583.1         NaN  53201.3
# 1995-04-01  74455.3    64623.2      54786         NaN  53590.9
# 1995-05-01    75432    64530.4    54698.8         NaN  53678.2
#
# [5 rows x 48 columns]

# %%
properties3.columns
# Out:
# Index(['City of London', 'Barking & Dagenham', 'Barnet', 'Bexley', 'Brent',
#        'Bromley', 'Camden', 'Croydon', 'Ealing', 'Enfield', 'Greenwich',
#        'Hackney', 'Hammersmith & Fulham', 'Haringey', 'Harrow', 'Havering',
#        'Hillingdon', 'Hounslow', 'Islington', 'Kensington & Chelsea',
#        'Kingston upon Thames', 'Lambeth', 'Lewisham', 'Merton', 'Newham',
#        'Redbridge', 'Richmond upon Thames', 'Southwark', 'Sutton',
#        'Tower Hamlets', 'Waltham Forest', 'Wandsworth', 'Westminster',
#        'Unnamed: 34', 'Inner London', 'Outer London', 'Unnamed: 37',
#        'NORTH EAST', 'NORTH WEST', 'YORKS & THE HUMBER', 'EAST MIDLANDS',
#        'WEST MIDLANDS', 'EAST OF ENGLAND', 'LONDON', 'SOUTH EAST',
#        'SOUTH WEST', 'Unnamed: 47', 'England'],
#       dtype='object')

# %%
# We can see there are three Unnamed columns: 'Unnamed: 34', 'Unnamed: 37', 'Unnamed: 47'
# Let us check NaN values in those columns to check is it worth to keep them 
properties3.isnull().sum()
# Out:
# City of London            0
# Barking & Dagenham        0
# Barnet                    0
# Bexley                    0
# Brent                     0
# Bromley                   0
# Camden                    0
# Croydon                   0
# Ealing                    0
# Enfield                   0
# Greenwich                 0
# Hackney                   0
# Hammersmith & Fulham      0
# Haringey                  0
# Harrow                    0
# Havering                  0
# Hillingdon                0
# Hounslow                  0
# Islington                 0
# Kensington & Chelsea      0
# Kingston upon Thames      0
# Lambeth                   0
# Lewisham                  0
# Merton                    0
# Newham                    0
# Redbridge                 0
# Richmond upon Thames      0
# Southwark                 0
# Sutton                    0
# Tower Hamlets             0
# Waltham Forest            0
# Wandsworth                0
# Westminster               0
# Unnamed: 34             312
# Inner London              0
# Outer London              0
# Unnamed: 37             312
# NORTH EAST                0
# NORTH WEST                0
# YORKS & THE HUMBER        0
# EAST MIDLANDS             0
# WEST MIDLANDS             0
# EAST OF ENGLAND           0
# LONDON                    0
# SOUTH EAST                0
# SOUTH WEST                0
# Unnamed: 47             312
# England                   0
# dtype: int64

# %%
properties3.shape
# Out:
# (312, 48)

# %%
# Investigation abot the Unnamed columns shows that all the values in these columns are null values,
# hence we need to drop those columns.

# %%
properties4 = properties3.drop(['Unnamed: 34', 'Unnamed: 37', 'Unnamed: 47'], axis = 1)
properties4.columns
# Out:
# Index(['City of London', 'Barking & Dagenham', 'Barnet', 'Bexley', 'Brent',
#        'Bromley', 'Camden', 'Croydon', 'Ealing', 'Enfield', 'Greenwich',
#        'Hackney', 'Hammersmith & Fulham', 'Haringey', 'Harrow', 'Havering',
#        'Hillingdon', 'Hounslow', 'Islington', 'Kensington & Chelsea',
#        'Kingston upon Thames', 'Lambeth', 'Lewisham', 'Merton', 'Newham',
#        'Redbridge', 'Richmond upon Thames', 'Southwark', 'Sutton',
#        'Tower Hamlets', 'Waltham Forest', 'Wandsworth', 'Westminster',
#        'Inner London', 'Outer London', 'NORTH EAST', 'NORTH WEST',
#        'YORKS & THE HUMBER', 'EAST MIDLANDS', 'WEST MIDLANDS',
#        'EAST OF ENGLAND', 'LONDON', 'SOUTH EAST', 'SOUTH WEST', 'England'],
#       dtype='object')

# %%
properties4.shape
# Out:
# (312, 45)

# %%
# It shows no Unnamed columns

# %%
properties4.head()
# Out:
#            City of London Barking & Dagenham   Barnet   Bexley    Brent  \
# Unnamed: 0
# 1995-01-01          91449            50460.2  93284.5  64958.1  71306.6
# 1995-02-01        82202.8            51085.8  93190.2  64787.9  72022.3
# 1995-03-01        79120.7              51269  92247.5  64367.5  72015.8
# 1995-04-01        77101.2            53133.5  90762.9  64277.7  72965.6
# 1995-05-01        84409.1            53042.2    90258  63997.1    73704
#
#             Bromley  Camden  Croydon   Ealing  Enfield  ... NORTH EAST  \
# Unnamed: 0                                              ...
# 1995-01-01  81671.5  120933  69158.2  79885.9  72514.7  ...    42076.4
# 1995-02-01  81657.6  119509  68951.1  80897.1  73155.2  ...      42572
# 1995-03-01  81449.3  120282  68712.4  81379.9  72190.4  ...    42369.7
# 1995-04-01  81124.4  120098    68610  82188.9  71442.9  ...    42095.8
# 1995-05-01  81542.6  119929  68844.9  82077.1  70630.8  ...    43266.5
#
#            NORTH WEST YORKS & THE HUMBER EAST MIDLANDS WEST MIDLANDS  \
# Unnamed: 0
# 1995-01-01    43958.5            44803.4       45544.5       48527.5
# 1995-02-01    43925.4            44528.8       46051.6       49341.3
# 1995-03-01    44434.9            45200.5       45383.8       49442.2
# 1995-04-01    44267.8            45614.3       46124.2       49455.9
# 1995-05-01    44223.6              44831         45878       50369.7
#
#            EAST OF ENGLAND   LONDON SOUTH EAST SOUTH WEST  England
# Unnamed: 0
# 1995-01-01         56701.6  74435.8    64018.9    54705.2  53202.8
# 1995-02-01         56593.6  72777.9      63715    54356.1  53096.2
# 1995-03-01         56171.2  73896.8    64113.6    53583.1  53201.3
# 1995-04-01         56567.9  74455.3    64623.2      54786  53590.9
# 1995-05-01         56479.8    75432    64530.4    54698.8  53678.2
#
# [5 rows x 45 columns]

# %%
# Calculate the average rent per month
columns_list = properties4.columns
properties5 = (properties4.loc[:, columns_list].resample('A').sum())/12
properties5.head()
# Out:
#             City of London  Barking & Dagenham         Barnet        Bexley  \
# Unnamed: 0
# 1995-12-31    99085.008156        51817.969390   91792.537433  64291.532845
# 1996-12-31   105651.057557        51718.192690   94000.445448  65490.417234
# 1997-12-31   117113.442375        55974.262309  106883.185546  70789.406603
# 1998-12-31   148031.894542        60285.821083  122359.468033  80632.020822
# 1999-12-31   171300.061875        65320.934441  136004.512067  86777.715903
#
#                     Brent        Bromley         Camden       Croydon  \
# Unnamed: 0
115686       94200       74706    70070
#
# [5 rows x 45 columns]

# %%
#import datetime
#yearonly = properties3.index.year
#yearonly

# %%
#properties3.reindex(yearonly)

# %%
properties6.index = properties6.index.map(lambda t: t.year)
properties6.head()
# Out:
#             City of London  Barking & Dagenham  Barnet  Bexley   Brent  \
# Unnamed: 0
# 1995                 99085               51817   91792   64291   73029
# 1996                105651               51718   94000   65490   75235
# 1997                117113               55974  106883   70789   86749
# 1998                148031               60285  122359   80632  100692
# 1999                171300               65320  136004   86777  112157
#
#             Bromley  Camden  Croydon  Ealing  Enfield  ...  NORTH EAST  \
# Unnamed: 0                                             ...
# 1995          81967  120367    68923   81218    71984  ...       42287
# 1996          83547  133810    69713   83389    74062  ...       42326
# 1997          94224  150142    77674   97805    83609  ...       43909
# 1998         108286  170688    88143  111343    93030  ...       45383
# 1999         120874  191090    97173  126278   101986  ...       46999
#
#             NORTH WEST  YORKS & THE HUMBER  EAST MIDLANDS  WEST MIDLANDS  \
# Unnamed: 0
# 1995             43927               44899          45680          49428
# 1996             43928               44820          46160          50047
# 1997             45874               46323          49253          53634
# 1998             47669               47655          52216          56912
# 1999             50144               49489          55833          60953
#
#             EAST OF ENGLAND  LONDON  SOUTH EAST  SOUTH WEST  England
# Unnamed: 0
# 1995                  56306   74721       64478       54214    53322
# 1996                  56805   78166       66107       55374    54151
# 1997                  62930   89943       74944       60990    59160
# 1998                  69729  102110       84477       67022    64301
# 1999                  76768  115686       94200       74706    70070
#
# [5 rows x 45 columns]

# %% [markdown]
# **2.3. Cleaning the data (part 2)**
#
# You might we have to **rename** a couple columns. How do you do this? The clue's pretty bold...

# %%
properties6.index.name = 'Year'
properties6.head()
# Out:
#       City of London  Barking & Dagenham  Barnet  Bexley   Brent  Bromley  \
# Year
# 1995           99085               51817   91792   64291   73029    81967
# 1996          105651               51718   94000   65490   75235    83547
# 1997          117113               55974  106883   70789   86749    94224
# 1998          148031               60285  122359   80632  100692   108286
# 1999          171300               65320  136004   86777  112157   120874
#
#       Camden  Croydon  Ealing  Enfield  ...  NORTH EAST  NORTH WEST  \
# Year                                    ...
# 1995  120367    68923   81218    71984  ...       42287       43927
# 1996  133810    69713   83389    74062  ...       42326       43928
# 1997  150142    77674   97805    83609  ...       43909       45874
# 1998  170688    88143  111343    93030  ...       45383       47669
# 1999  191090    97173  126278   101986  ...       46999       50144
#
#       YORKS & THE HUMBER  EAST MIDLANDS  WEST MIDLANDS  EAST OF ENGLAND  \
# Year
# 1995               44899          45680          49428            56306
# 1996               44820          46160          50047            56805
# 1997               46323          49253          53634            62930
# 1998               47655          52216          56912            69729
# 1999               49489          55833          60953            76768
#
#       LONDON  SOUTH EAST  SOUTH WEST  England
# Year
# 1995   74721       64478       54214    53322
# 1996   78166       66107       55374    54151
# 1997   89943       74944       60990    59160
# 1998  102110       84477       67022    64301
# 1999  115686       94200       74706    70070
#
# [5 rows x 45 columns]

# %%
 # Here you can see the index name has been changed to 'Year'.

# %% [markdown]
# **2.4.Transforming the data**
#
# Remember what Wes McKinney said about tidy data?
#
# You might need to **melt** your DataFrame here.

# %%
properties7 = properties6.reset_index()
properties7.head()
# Out:
#    Year  City of London  Barking & Dagenham  Barnet  Bexley   Brent  Bromley  \
# 0  1995           99085               51817   91792   64291   73029    81967
# 1  1996          105651               51718   94000   65490   75235    83547
# 2  1997          117113               55974  106883   70789   86749    94224
# 3  1998          148031               60285  122359   80632  100692   108286
# 4  1999          171300               65320  136004   86777  112157   120874
#
#    Camden  Croydon  Ealing  ...  NORTH EAST  NORTH WEST  YORKS & THE HUMBER  \
# 0  120367    68923   81218  ...       42287       43927               44899
# 1  133810    69713   83389  ...       42326       43928               44820
# 2  150142    77674   97805  ...       43909       45874               46323
# 3  170688    88143  111343  ...       45383       47669               47655
# 4  191090    97173  126278  ...       46999       50144               49489
#
#    EAST MIDLANDS  WEST MIDLANDS  EAST OF ENGLAND  LONDON  SOUTH EAST  \
# 0          45680          49428            56306   74721       64478
# 1          46160          50047            56805   78166       66107
# 2          49253          53634            62930   89943       74944
# 3          52216          56912            69729  102110       84477
# 4          55833          60953            76768  115686       94200
#
#    SOUTH WEST  England
# 0       54214    53322
# 1       55374    54151
# 2       60990    59160
# 3       67022    64301
# 4       74706    70070
#
# [5 rows x 46 columns]

# %%
properties7_columns = properties7.columns 
properties7_columns
properties7_melt = properties7.melt(id_vars = ['Year'], value_vars = properties7_columns[1:], value_name = 'Price')
properties7_melt.head(15)
# Out:
#     Year        variable   Price
# 0   1995  City of London   99085
# 1   1996  City of London  105651
# 2   1997  City of London  117113
# 3   1998  City of London  148031
# 4   1999  City of London  171300
# 5   2000  City of London  218679
# 6   2001  City of London  250625
# 7   2002  City of London  269632
# 8   2003  City of London  270811
# 9   2004  City of London  301032
# 10  2005  City of London  311783
# 11  2006  City of London  338518
# 12  2007  City of London  433838
# 13  2008  City of London  427296
# 14  2009  City of London  383417

# %% [markdown]
# Remember to make sure your column data types are all correct. Average prices, for example, should be floating point numbers...

# %%
# checking the datatypes of each cloumns
properties7_melt.dtypes
# Out:
# Year         int64
# variable    object
# Price        int32
# dtype: object

# %% [markdown]
# **2.5. Cleaning the data (part 3)**
#
# Do we have an equal number of observations in the ID, Average Price, Month, and London Borough columns? Remember that there are only 32 London Boroughs. How many entries do you have in that column?
#
# Check out the contents of the London Borough column, and if you find null values, get rid of them however you see fit.

# %%
 properties6.isnull().sum()
# Out:
# City of London          0
# Barking & Dagenham      0
# Barnet                  0
# Bexley                  0
# Brent                   0
# Bromley                 0
# Camden                  0
# Croydon                 0
# Ealing                  0
# Enfield                 0
# Greenwich               0
# Hackney                 0
# Hammersmith & Fulham    0
# Haringey                0
# Harrow                  0
# Havering                0
# Hillingdon              0
# Hounslow                0
# Islington               0
# Kensington & Chelsea    0
# Kingston upon Thames    0
# Lambeth                 0
# Lewisham                0
# Merton                  0
# Newham                  0
# Redbridge               0
# Richmond upon Thames    0
# Southwark               0
# Sutton                  0
# Tower Hamlets           0
# Waltham Forest          0
# Wandsworth              0
# Westminster             0
# Inner London            0
# Outer London            0
# NORTH EAST              0
# NORTH WEST              0
# YORKS & THE HUMBER      0
# EAST MIDLANDS           0
# WEST MIDLANDS           0
# EAST OF ENGLAND         0
# LONDON                  0
# SOUTH EAST              0
# SOUTH WEST              0
# England                 0
# dtype: int64

# %%
 properties6.dtypes
# Out:
# City of London          int32
# Barking & Dagenham      int32
# Barnet                  int32
# Bexley                  int32
# Brent                   int32
# Bromley                 int32
# Camden                  int32
# Croydon                 int32
# Ealing                  int32
# Enfield                 int32
# Greenwich               int32
# Hackney                 int32
# Hammersmith & Fulham    int32
# Haringey                int32
# Harrow                  int32
# Havering                int32
# Hillingdon              int32
# Hounslow                int32
# Islington               int32
# Kensington & Chelsea    int32
# Kingston upon Thames    int32
# Lambeth                 int32
# Lewisham                int32
# Merton                  int32
# Newham                  int32
# Redbridge               int32
# Richmond upon Thames    int32
# Southwark               int32
# Sutton                  int32
# Tower Hamlets           int32
# Waltham Forest          int32
# Wandsworth              int32
# Westminster             int32
# Inner London            int32
# Outer London            int32
# NORTH EAST              int32
# NORTH WEST              int32
# YORKS & THE HUMBER      int32
# EAST MIDLANDS           int32
# WEST MIDLANDS           int32
# EAST OF ENGLAND         int32
# LONDON                  int32
# SOUTH EAST              int32
# SOUTH WEST              int32
# England                 int32
# dtype: object

# %%
 properties6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26 entries, 1995 to 2020
# Data columns (total 45 columns):
# City of London          26 non-null int32
# Barking & Dagenham      26 non-null int32
# Barnet                  26 non-null int32
# Bexley                  26 non-null int32
# Brent                   26 non-null int32
# Bromley                 26 non-null int32
# Camden                  26 non-null int32
# Croydon                 26 non-null int32
# Ealing                  26 non-null int32
# Enfield                 26 non-null int32
# Greenwich               26 non-null int32
# Hackney                 26 non-null int32
# Hammersmith & Fulham    26 non-null int32
# Haringey                26 non-null int32
# Harrow                  26 non-null int32
# Havering                26 non-null int32
# Hillingdon              26 non-null int32
# Hounslow                26 non-null int32
# Islington               26 non-null int32
# Kensington & Chelsea    26 non-null int32
# Kingston upon Thames    26 non-null int32
# Lambeth                 26 non-null int32
# Lewisham                26 non-null int32
# Merton                  26 non-null int32
# Newham                  26 non-null int32
# Redbridge               26 non-null int32
# Richmond upon Thames    26 non-null int32
# Southwark               26 non-null int32
# Sutton                  26 non-null int32
# Tower Hamlets           26 non-null int32
# Waltham Forest          26 non-null int32
# Wandsworth              26 non-null int32
# Westminster             26 non-null int32
# Inner London            26 non-null int32
# Outer London            26 non-null int32
# NORTH EAST              26 non-null int32
# NORTH WEST              26 non-null int32
# YORKS & THE HUMBER      26 non-null int32
# EAST MIDLANDS           26 non-null int32
# WEST MIDLANDS           26 non-null int32
# EAST OF ENGLAND         26 non-null int32
# LONDON                  26 non-null int32
# SOUTH EAST              26 non-null int32
# SOUTH WEST              26 non-null int32
# England                 26 non-null int32
# dtypes: int32(45)
# memory usage: 4.8 KB

# %%
# The info shows all the columns have 26 entries in all columns.

# %%
properties6.shape
# Out:
# (26, 45)

# %%
# List of all the borough names from Wikipedia 
Greater_London_32_boroughs = ['Barking and Dagenham', 'Barnet', 'Bexley', 'Brent', 'Bromley', 'Camden', 'Croydon',
                              'Ealing', 'Enfield', 'Greenwich', 'Hackney', 'Hammersmith and Fulham', 'Haringey',
                             'Harrow', 'Havering', 'Hillingdon', 'Hounslow', 'Islington', 'Kensington and Chelsea',
                             'Kingston upon Thames', 'Lambeth', 'Lewisham', 'Merton', 'Newham', 'Redbridge', 
                              'Richmond upon Thames', 'Southwark', 'Sutton', 'Tower Hamlets', 'Waltham Forest',
                             'Wandsworth', 'Westminster']
len(set(Greater_London_32_boroughs))
# Out:
# 32

# %%
print(sorted(Greater_London_32_boroughs))
# Out:
# ['Barking and Dagenham', 'Barnet', 'Bexley', 'Brent', 'Bromley', 'Camden', 'Croydon', 'Ealing', 'Enfield', 'Greenwich', 'Hackney', 'Hammersmith and Fulham', 'Haringey', 'Harrow', 'Havering', 'Hillingdon', 'Hounslow', 'Islington', 'Kensington and Chelsea', 'Kingston upon Thames', 'Lambeth', 'Lewisham', 'Merton', 'Newham', 'Redbridge', 'Richmond upon Thames', 'Southwark', 'Sutton', 'Tower Hamlets', 'Waltham Forest', 'Wandsworth', 'Westminster']

# %%
# List of columns names from properties4 dataframe.
properties6.columns
# Out:
# Index(['City of London', 'Barking & Dagenham', 'Barnet', 'Bexley', 'Brent',
#        'Bromley', 'Camden', 'Croydon', 'Ealing', 'Enfield', 'Greenwich',
#        'Hackney', 'Hammersmith & Fulham', 'Haringey', 'Harrow', 'Havering',
#        'Hillingdon', 'Hounslow', 'Islington', 'Kensington & Chelsea',
#        'Kingston upon Thames', 'Lambeth', 'Lewisham', 'Merton', 'Newham',
#        'Redbridge', 'Richmond upon Thames', 'Southwark', 'Sutton',
#        'Tower Hamlets', 'Waltham Forest', 'Wandsworth', 'Westminster',
#        'Inner London', 'Outer London', 'NORTH EAST', 'NORTH WEST',
#        'YORKS & THE HUMBER', 'EAST MIDLANDS', 'WEST MIDLANDS',
#        'EAST OF ENGLAND', 'LONDON', 'SOUTH EAST', 'SOUTH WEST', 'England'],
#       dtype='object')

# %%
# Note: some of the column names in the properties6 dataframe are not in the Greater_London_32_borough list

# %%
#borough_table = pd.DataFrame({'boroughs': Greater_London_32_boroughs, 'borough_columns':properties4.columns[1:]})
#borough_table
# This gives error as the number of elements in two columns are different

# %%
# Let us list which are not present in Greater_London_32_borough list
list1 = []
for element in properties6.columns:
    if element not in Greater_London_32_boroughs:
        list1.append(element)
print(list1)
print('\n\n',len(list1))
# Out:
# ['City of London', 'Barking & Dagenham', 'Hammersmith & Fulham', 'Kensington & Chelsea', 'Inner London', 'Outer London', 'NORTH EAST', 'NORTH WEST', 'YORKS & THE HUMBER', 'EAST MIDLANDS', 'WEST MIDLANDS', 'EAST OF ENGLAND', 'LONDON', 'SOUTH EAST', 'SOUTH WEST', 'England']
#
#
#  16

# %%
# Note: Though some columns does not represent a borough, 3 boroughs (1. Barking & Dagenham, 2.Hammersmith & Fulham', 
# 3. Kensington & Chelsea) though they are boroughs but have been listed  differently. The "and" within the name has been written as "&". 
# So we need to change that.

# %%
# Rename the columns, also include inplace = True
properties6.rename(columns = {'Barking & Dagenham':'Barking and Dagenham', 'Hammersmith & Fulham': 'Hammersmith and Fulham', 'Kensington & Chelsea': 'Kensington and Chelsea'}, inplace = True)
properties6.head()
# Out:
#       City of London  Barking and Dagenham  Barnet  Bexley   Brent  Bromley  \
# Year
# 1995           99085                 51817   91792   64291   73029    81967
# 1996          105651                 51718   94000   65490   75235    83547
# 1997          117113                 55974  106883   70789   86749    94224
# 1998          148031                 60285  122359   80632  100692   108286
# 1999          171300                 65320  136004   86777  112157   120874
#
#       Camden  Croydon  Ealing  Enfield  ...  NORTH EAST  NORTH WEST  \
# Year                                    ...
# 1995  120367    68923   81218    71984  ...       42287       43927
# 1996  133810    69713   83389    74062  ...       42326       43928
# 1997  150142    77674   97805    83609  ...       43909       45874
# 1998  170688    88143  111343    93030  ...       45383       47669
# 1999  191090    97173  126278   101986  ...       46999       50144
#
#       YORKS & THE HUMBER  EAST MIDLANDS  WEST MIDLANDS  EAST OF ENGLAND  \
# Year
# 1995               44899          45680          49428            56306
# 1996               44820          46160          50047            56805
# 1997               46323          49253          53634            62930
# 1998               47655          52216          56912            69729
# 1999               49489          55833          60953            76768
#
#       LONDON  SOUTH EAST  SOUTH WEST  England
# Year
# 1995   74721       64478       54214    53322
# 1996   78166       66107       55374    54151
# 1997   89943       74944       60990    59160
# 1998  102110       84477       67022    64301
# 1999  115686       94200       74706    70070
#
# [5 rows x 45 columns]

# %%
print(properties6.columns) # New column names
print("\n\n", len(properties6.columns)) # Number of column names
# Out:
# Index(['City of London', 'Barking and Dagenham', 'Barnet', 'Bexley', 'Brent',
#        'Bromley', 'Camden', 'Croydon', 'Ealing', 'Enfield', 'Greenwich',
#        'Hackney', 'Hammersmith and Fulham', 'Haringey', 'Harrow', 'Havering',
#        'Hillingdon', 'Hounslow', 'Islington', 'Kensington and Chelsea',
#        'Kingston upon Thames', 'Lambeth', 'Lewisham', 'Merton', 'Newham',
#        'Redbridge', 'Richmond upon Thames', 'Southwark', 'Sutton',
#        'Tower Hamlets', 'Waltham Forest', 'Wandsworth', 'Westminster',
#        'Inner London', 'Outer London', 'NORTH EAST', 'NORTH WEST',
#        'YORKS & THE HUMBER', 'EAST MIDLANDS', 'WEST MIDLANDS',
#        'EAST OF ENGLAND', 'LONDON', 'SOUTH EAST', 'SOUTH WEST', 'England'],
#       dtype='object')
#
#
#  45

# %%
# There are 32 boroughs in Greater London and in the dataframe there are 45 borough columns, we have to check 
# which columns are not real boroughs within Greater London and how many are there in total. 
list2 = []
for element in properties6.columns:
    if element not in Greater_London_32_boroughs:
        list2.append(element)
print(list2) # Does not belong as borough in Greater London
len(list2)   # Total number column names those are not borough
# Out:
# ['City of London', 'Inner London', 'Outer London', 'NORTH EAST', 'NORTH WEST', 'YORKS & THE HUMBER', 'EAST MIDLANDS', 'WEST MIDLANDS', 'EAST OF ENGLAND', 'LONDON', 'SOUTH EAST', 'SOUTH WEST', 'England']
# 13

# %%
# In the previous shell we listed all the columns which are not boroughs within Greater London. 
# Let us delete those rows before we carry out any analysis 
for element in properties6.columns:
    if element not in Greater_London_32_boroughs:
        del properties6[element]
properties6.head()
# See the number of borough columns in the properties dataframe  
print(len(properties6.columns))
print(properties6.shape)
# Out:
# 32
# (26, 32)

# %%
properties6.describe()
# Out:
#        Barking and Dagenham         Barnet         Bexley          Brent  \
# count             26.000000      26.000000      26.000000      26.000000
# mean          164869.538462  312870.307692  195025.000000  278169.230769
# std            80748.665535  147273.851758   90075.063331  140163.146999
# min            51718.000000   91792.000000   64291.000000   73029.000000
# 25%            94553.250000  194358.750000  121594.500000  164439.750000
# 50%           164664.000000  313009.000000  196251.500000  275698.500000
# 75%           197718.000000  416464.750000  236711.750000  380929.000000
# max           303024.000000  538281.000000  343784.000000  492845.000000
#
#              Bromley         Camden        Croydon         Ealing  \
# count      26.000000      26.000000      26.000000      26.000000
# mean   260564.846154  480617.423077  215236.384615  281848.423077
# std    117804.288226  250526.529308   98500.095221  133923.418715
# min     81967.000000  120367.000000   68923.000000   81218.000000
# 25%    168259.750000  287490.250000  138637.250000  177249.000000
# 50%    260479.000000  460556.500000  213769.000000  278433.000000
# 75%    335060.000000  734226.250000  265119.750000  384551.250000
# max    443409.000000  843066.000000  375364.000000  484592.000000
#
#              Enfield      Greenwich  ...         Merton         Newham  \
# count      26.000000      26.000000  ...      26.000000      26.000000
# mean   229708.576923  219635.000000  ...  289918.384615  201860.423077
# std    106740.525121  109501.117022  ...  146140.566327  102811.946957
# min     71984.000000   63389.000000  ...   80500.000000   54574.000000
# 25%    141732.500000  131220.250000  ...  174213.000000  115936.000000
# 50%    231992.000000  219591.500000  ...  284728.000000  203875.000000
# 75%    286287.250000  287113.000000  ...  401118.000000  250331.000000
# max    396631.000000  397238.000000  ...  526179.000000  371741.000000
#
#            Redbridge  Richmond upon Thames      Southwark         Sutton  \
# count      26.000000             26.000000      26.000000      26.000000
# mean   241743.730769         393208.000000  283287.730769  222995.500000
# std    112652.812582         186386.235445  152167.132414  100490.923215
# min     72580.000000         109892.000000   64260.000000   70291.000000
# 25%    148532.250000         248922.000000  169535.500000  144064.000000
# 50%    246031.500000         389389.500000  275409.500000  224374.500000
# 75%    296827.500000         555820.000000  411012.500000  281349.500000
# max    424738.000000         683294.000000  515883.000000  379428.000000
#
#        Tower Hamlets  Waltham Forest     Wandsworth   Westminster
# count      26.000000       26.000000      26.000000  2.600000e+01
# mean   265192.807692   228576.076923  351874.153846  5.584532e+05
# std    129941.353809   127163.044962  178887.377222  3.127522e+05
# min     63652.000000    61279.000000   88829.000000  1.336890e+05
# 25%    168700.750000   126166.500000  212085.500000  3.069842e+05
# 50%    270498.000000   215306.000000  352094.500000  5.232610e+05
# 75%    363943.500000   299766.750000  522737.250000  8.895195e+05
# max    465025.000000   452266.000000  617921.000000  1.064771e+06
#
# [8 rows x 32 columns]

# %%
properties6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26 entries, 1995 to 2020
# Data columns (total 32 columns):
# Barking and Dagenham      26 non-null int32
# Barnet                    26 non-null int32
# Bexley                    26 non-null int32
# Brent                     26 non-null int32
# Bromley                   26 non-null int32
# Camden                    26 non-null int32
# Croydon                   26 non-null int32
# Ealing                    26 non-null int32
# Enfield                   26 non-null int32
# Greenwich                 26 non-null int32
# Hackney                   26 non-null int32
# Hammersmith and Fulham    26 non-null int32
# Haringey                  26 non-null int32
# Harrow                    26 non-null int32
# Havering                  26 non-null int32
# Hillingdon                26 non-null int32
# Hounslow                  26 non-null int32
# Islington                 26 non-null int32
# Kensington and Chelsea    26 non-null int32
# Kingston upon Thames      26 non-null int32
# Lambeth                   26 non-null int32
# Lewisham                  26 non-null int32
# Merton                    26 non-null int32
# Newham                    26 non-null int32
# Redbridge                 26 non-null int32
# Richmond upon Thames      26 non-null int32
# Southwark                 26 non-null int32
# Sutton                    26 non-null int32
# Tower Hamlets             26 non-null int32
# Waltham Forest            26 non-null int32
# Wandsworth                26 non-null int32
# Westminster               26 non-null int32
# dtypes: int32(32)
# memory usage: 3.5 KB

# %%
properties6.dtypes
# Out:
# Barking and Dagenham      int32
# Barnet                    int32
# Bexley                    int32
# Brent                     int32
# Bromley                   int32
# Camden                    int32
# Croydon                   int32
# Ealing                    int32
# Enfield                   int32
# Greenwich                 int32
# Hackney                   int32
# Hammersmith and Fulham    int32
# Haringey                  int32
# Harrow                    int32
# Havering                  int32
# Hillingdon                int32
# Hounslow                  int32
# Islington                 int32
# Kensington and Chelsea    int32
# Kingston upon Thames      int32
# Lambeth                   int32
# Lewisham                  int32
# Merton                    int32
# Newham                    int32
# Redbridge                 int32
# Richmond upon Thames      int32
# Southwark                 int32
# Sutton                    int32
# Tower Hamlets             int32
# Waltham Forest            int32
# Wandsworth                int32
# Westminster               int32
# dtype: object

# %% [markdown]
# **2.6. Visualizing the data**
#
# To visualize the data, why not subset on a particular London Borough? Maybe do a line plot of Month against Average Price?

# %%
import matplotlib.pyplot as plt
properties6.plot(figsize = (8, 8), rot = 60)
plt.xlabel('Year')
plt.ylabel('Avg. House Price(euros)')
plt.title('Avg.Housing Price in Greater London boroughs')
plt.legend(loc = 'upper center')
plt.show()

# %%
# calculate the difference of the cosecutive year avg. housing price
properties_price_difference_consecutive_years = properties6.diff()
properties_price_difference_consecutive_years.head()
# Out:
#       Barking and Dagenham   Barnet  Bexley    Brent  Bromley   Camden  \
# Year
# 1995                   NaN      NaN     NaN      NaN      NaN      NaN
# 1996                 -99.0   2208.0  1199.0   2206.0   1580.0  13443.0
# 1997                4256.0  12883.0  5299.0  11514.0  10677.0  16332.0
# 1998                4311.0  15476.0  9843.0  13943.0  14062.0  20546.0
# 1999                5035.0  13645.0  6145.0  11465.0  12588.0  20402.0
#
#       Croydon   Ealing  Enfield  Greenwich  ...   Merton  Newham  Redbridge  \
# Year                                        ...
# 1995      NaN      NaN      NaN        NaN  ...      NaN     NaN        NaN
# 1996    790.0   2171.0   2078.0     1797.0  ...   3499.0  1173.0     2778.0
# 1997   7961.0  14416.0   9547.0     6881.0  ...  11700.0  5224.0     8013.0
# 1998  10469.0  13538.0   9421.0     9465.0  ...  12350.0  6700.0    11143.0
# 1999   9030.0  14935.0   8956.0     9347.0  ...  13852.0  6854.0     8426.0
#
#       Richmond upon Thames  Southwark   Sutton  Tower Hamlets  Waltham Forest  \
# Year
# 1995                   NaN        NaN      NaN            NaN             NaN
# 1996                7415.0     5857.0   1360.0         6442.0           898.0
# 1997               19349.0     9608.0   9443.0        15665.0          6051.0
# 1998               26300.0    11680.0  10993.0        10746.0          7329.0
# 1999               18816.0    18862.0   8782.0        16530.0          8264.0
#
#       Wandsworth  Westminster
# Year
# 1995         NaN          NaN
# 1996      3441.0       5499.0
# 1997     15838.0      26259.0
# 1998     17298.0      25084.0
# 1999     19933.0      23511.0
#
# [5 rows x 32 columns]

# %%
# As 1st row (1995) contains only the NaN value, it needed to be dropped for plotting.
properties_price_difference_consecutive_years2 = properties_price_difference_consecutive_years.drop(1995, axis = 0 )
properties_price_difference_consecutive_years2.head()
# Out:
#       Barking and Dagenham   Barnet   Bexley    Brent  Bromley   Camden  \
# Year
# 1996                 -99.0   2208.0   1199.0   2206.0   1580.0  13443.0
# 1997                4256.0  12883.0   5299.0  11514.0  10677.0  16332.0
# 1998                4311.0  15476.0   9843.0  13943.0  14062.0  20546.0
# 1999                5035.0  13645.0   6145.0  11465.0  12588.0  20402.0
# 2000               12229.0  31948.0  16409.0  28805.0  26952.0  56024.0
#
#       Croydon   Ealing  Enfield  Greenwich  ...   Merton   Newham  Redbridge  \
# Year                                        ...
# 1996    790.0   2171.0   2078.0     1797.0  ...   3499.0   1173.0     2778.0
# 1997   7961.0  14416.0   9547.0     6881.0  ...  11700.0   5224.0     8013.0
# 1998  10469.0  13538.0   9421.0     9465.0  ...  12350.0   6700.0    11143.0
# 1999   9030.0  14935.0   8956.0     9347.0  ...  13852.0   6854.0     8426.0
# 2000  21604.0  27031.0  19853.0    19283.0  ...  29704.0  18362.0    21439.0
#
#       Richmond upon Thames  Southwark   Sutton  Tower Hamlets  Waltham Forest  \
# Year
# 1996                7415.0     5857.0   1360.0         6442.0           898.0
# 1997               19349.0     9608.0   9443.0        15665.0          6051.0
# 1998               26300.0    11680.0  10993.0        10746.0          7329.0
# 1999               18816.0    18862.0   8782.0        16530.0          8264.0
# 2000               46094.0    31999.0  25083.0        28252.0         19209.0
#
#       Wandsworth  Westminster
# Year
# 1996      3441.0       5499.0
# 1997     15838.0      26259.0
# 1998     17298.0      25084.0
# 1999     19933.0      23511.0
# 2000     38936.0      46450.0
#
# [5 rows x 32 columns]

# %%
# The price difference for all 32 boroughs are plotted against years 
properties_price_difference_consecutive_years2.plot(figsize = (10, 10))
plt.xlabel('Year')
plt.ylabel('Price difference in Euros between consecutive years')
plt.title("Price difference in euros between consecutive Years")
plt.legend(loc = 'lower left')
plt.show()

# %%
 # Find out county name with maximum average price change between consecutive years
def find_max(data):
    list_column_max_and_column_name = [] # Make a list of tuple, where each tuple consists of "column_name" and "max value in that column"
    list_of_max_each_column = []
    for col in data.columns: 
        list_column_max_and_column_name.append((col, data[col].max()))
        list_of_max_each_column.append(data[col].max()) 
    
    max_overall = max(list_of_max_each_column)
    
    for i in range(len(list_column_max_and_column_name)):
        column_name, column_max_value = list_column_max_and_column_name[i]
        if column_max_value != max_overall:
            continue
        
        return column_name, column_max_value, list_column_max_and_column_name, max_overall
    
    
print(find_max(properties_price_difference_consecutive_years2)[0],'borough has maximum avg monthly price change of', find_max(properties_price_difference_consecutive_years2)[1], 'euros')
print('\n\n', pd.Series(find_max(properties_price_difference_consecutive_years2)[2]))
print('\n\n', "Max price flactuation", find_max(properties_price_difference_consecutive_years2)[3])
# Out:
# Kensington and Chelsea borough has maximum avg monthly price change of 161833.0 euros
#
#
#  0        (Barking and Dagenham, 40459.0)
# 1                      (Barnet, 55593.0)
# 2                      (Bexley, 47354.0)
# 3                       (Brent, 55032.0)
# 4                     (Bromley, 51188.0)
# 5                      (Camden, 89039.0)
# 6                     (Croydon, 48782.0)
# 7                      (Ealing, 61951.0)
# 8                     (Enfield, 49986.0)
# 9                   (Greenwich, 44952.0)
# 10                    (Hackney, 83720.0)
# 11     (Hammersmith and Fulham, 89570.0)
# 12                   (Haringey, 63574.0)
# 13                     (Harrow, 47809.0)
# 14                   (Havering, 49959.0)
# 15                 (Hillingdon, 48043.0)
# 16                   (Hounslow, 35024.0)
# 17                  (Islington, 89405.0)
# 18    (Kensington and Chelsea, 161833.0)
# 19       (Kingston upon Thames, 60367.0)
# 20                    (Lambeth, 70659.0)
# 21                   (Lewisham, 54997.0)
# 22                     (Merton, 75432.0)
# 23                     (Newham, 50398.0)
# 24                  (Redbridge, 48042.0)
# 25       (Richmond upon Thames, 84940.0)
# 26                  (Southwark, 67018.0)
# 27                     (Sutton, 42371.0)
# 28              (Tower Hamlets, 73190.0)
# 29             (Waltham Forest, 60669.0)
# 30                 (Wandsworth, 87111.0)
# 31               (Westminster, 132730.0)
# dtype: object
#
#
#  Max price flactuation 161833.0

# %%
# Function to calculate avg. price range (max-min) through all these years
def find_max_range(data):
    list_with_range_and_column = []                         # Make list of column name and range for each column
    list_of_ranges = []                                     # Make list of ranges 
    for col in data.columns:
        range_each_column = max(data[col]) - min(data[col]) # calculate the range for each column
        list_with_range_and_column.append((col, range_each_column))
        list_of_ranges.append(range_each_column)
    maximum_range = max(list_of_ranges)                     # Find the maximum range 
    for i in range(len(list_with_range_and_column)):
        column_name1, column_max_value1 = list_with_range_and_column[i] # Unzip the tuple within list
        if column_max_value1 != maximum_range:
            continue
        return column_name1, column_max_value1, list_with_range_and_column
print('Maximum price range', find_max_range(properties6)[:2])
print('Maximum price difference range', find_max_range(properties_price_difference_consecutive_years2)[:2])
print('\n\n', 'List of column names and price range', pd.Series(find_max_range(properties6)[2]))
# Out:
# Maximum price range ('Kensington and Chelsea', 1171023)
# Maximum price difference range ('Kensington and Chelsea', 284291.0)
#
#
#  List of column names and price range 0        (Barking and Dagenham, 251306)
# 1                      (Barnet, 446489)
# 2                      (Bexley, 279493)
# 3                       (Brent, 419816)
# 4                     (Bromley, 361442)
# 5                      (Camden, 722699)
# 6                     (Croydon, 306441)
# 7                      (Ealing, 403374)
# 8                     (Enfield, 324647)
# 9                   (Greenwich, 333849)
# 10                    (Hackney, 519132)
# 11     (Hammersmith and Fulham, 637595)
# 12                   (Haringey, 479058)
# 13                     (Harrow, 387244)
# 14                   (Havering, 302545)
# 15                 (Hillingdon, 339831)
# 16                   (Hounslow, 335979)
# 17                  (Islington, 568064)
# 18    (Kensington and Chelsea, 1171023)
# 19       (Kingston upon Thames, 414252)
# 20                    (Lambeth, 461933)
# 21                   (Lewisham, 365104)
# 22                     (Merton, 445679)
# 23                     (Newham, 317167)
# 24                  (Redbridge, 352158)
# 25       (Richmond upon Thames, 573402)
# 26                  (Southwark, 451623)
# 27                     (Sutton, 309137)
# 28              (Tower Hamlets, 401373)
# 29             (Waltham Forest, 390987)
# 30                 (Wandsworth, 529092)
# 31                (Westminster, 931082)
# dtype: object

# %%
print('\n\n', 'This borough has maximum average price: ', find_max(properties6)[:2])
# Out:
#  This borough has maximum average price:  ('Kensington and Chelsea', 1363880)

# %%
# Find the year Kensington and Chelsa borough had maximum average price.
print('In the year of', properties6[properties6['Kensington and Chelsea'] == 1363880].index.values[0], 'Kensington and Chelsa borough had maximum avg. house price.')
# Out:
# In the year of 2018 Kensington and Chelsa borough had maximum avg. house price.

# %% [markdown]
# To limit the number of data points you have, you might want to extract the year from every month value your *Month* column.
#
# To this end, you *could* apply a ***lambda function***. Your logic could work as follows:
# 1. look through the `Month` column
# 2. extract the year from each individual value in that column
# 3. store that corresponding year as separate column.
#
# Whether you go ahead with this is up to you. Just so long as you answer our initial brief: which boroughs of London have seen the greatest house price increase, on average, over the past two decades?

# %%
# Extracting year from date column has been done in the beginning of the program.

# %% [markdown]
# **3. Modeling**
#
# Consider creating a function that will calculate a ratio of house prices, comparing the price of a house in 2018 to the price in 1998.
#
# Consider calling this function create_price_ratio.
#
# You'd want this function to:
# 1. Take a filter of dfg, specifically where this filter constrains the London_Borough, as an argument. For example, one admissible argument should be: dfg[dfg['London_Borough']=='Camden'].
# 2. Get the Average Price for that Borough, for the years 1998 and 2018.
# 4. Calculate the ratio of the Average Price for 1998 divided by the Average Price for 2018.
# 5. Return that ratio.
#
# Once you've written this function, you ultimately want to use it to iterate through all the unique London_Boroughs and work out the ratio capturing the difference of house prices between 1998 and 2018.
#
# Bear in mind: you don't have to write a function like this if you don't want to. If you can solve the brief otherwise, then great!
#
# ***Hint***: This section should test the skills you acquired in:
# - Python Data Science Toolbox - Part One, all modules

# %%
# Define the function "create_price_ratio" to calculate the price ratio between 2018 and 1998
def create_price_ratio(year_lower, year_upper, dfg):
    Borough_name_and_price_ratio = []
    Borough_name = []
    ratio = []
    for London_Borough in dfg.columns:
        price_ratio = dfg.loc[year_upper, London_Borough]/dfg.loc[year_lower, London_Borough]
        Borough_name_and_price_ratio.append((London_Borough, price_ratio))
        Borough_name.append(London_Borough)
        ratio.append(price_ratio)
    borough_price_series = pd.Series(ratio, index = Borough_name)
    series_max = borough_price_series.max()
    series_max_index = borough_price_series.idxmax()
    return borough_price_series, series_max, series_max_index
print("A series listing the ratios of prices for 2018 to 1998 \n\n", create_price_ratio(1998, 2018, properties6))
print("\n\n", create_price_ratio(1998, 2018, properties6)[2], "has seen maximum price ratio of", round(create_price_ratio(1998, 2018, properties6)[1], 1), '.')
# Out:
# A series listing the ratios of prices for 2018 to 1998
#
#  (Barking and Dagenham      4.896674
# Barnet                    4.358208
# Bexley                    4.248971
# Brent                     4.894580
# Bromley                   4.094795
# Camden                    4.935379
# Croydon                   4.201105
# Ealing                    4.311452
# Enfield                   4.263474
# Greenwich                 4.763087
# Hackney                   6.198318
# Hammersmith and Fulham    4.137818
# Haringey                  5.134660
# Harrow                    4.059201
# Havering                  4.325226
# Hillingdon                4.200274
# Hounslow                  3.976410
# Islington                 4.844083
# Kensington and Chelsea    5.082467
# Kingston upon Thames      4.270569
# Lambeth                   4.957753
# Lewisham                  5.449212
# Merton                    4.741303
# Newham                    5.305404
# Redbridge                 4.471200
# Richmond upon Thames      4.005161
# Southwark                 5.516493
# Sutton                    4.118518
# Tower Hamlets             4.626703
# Waltham Forest            5.834787
# Wandsworth                4.757739
# Westminster               5.353591
# dtype: float64, 6.198317950585531, 'Hackney')
#
#
#  Hackney has seen maximum price ratio of 6.2 .

# %%
# Make a table of year, borough which has maximum average price and how much for every year 
for year1 in properties6.index:
    x = pd.Series(properties6.loc[year1, :])
    maximum_avg_price = x.max()
    print(year1, x.idxmax(),  maximum_avg_price)
# Out:
# 1995 Kensington and Chelsea 192857
# 1996 Kensington and Chelsea 207156
# 1997 Kensington and Chelsea 246655
# 1998 Kensington and Chelsea 268350
# 1999 Kensington and Chelsea 311455
# 2000 Kensington and Chelsea 376802
# 2001 Kensington and Chelsea 420129
# 2002 Kensington and Chelsea 460382
# 2003 Kensington and Chelsea 460490
# 2004 Kensington and Chelsea 512186
# 2005 Kensington and Chelsea 520206
# 2006 Kensington and Chelsea 598007
# 2007 Kensington and Chelsea 746679
# 2008 Kensington and Chelsea 784834
# 2009 Kensington and Chelsea 705187
# 2010 Kensington and Chelsea 837314
# 2011 Kensington and Chelsea 908565
# 2012 Kensington and Chelsea 1009044
# 2013 Kensington and Chelsea 1126572
# 2014 Kensington and Chelsea 1288405
# 2015 Kensington and Chelsea 1302102
# 2016 Kensington and Chelsea 1276235
# 2017 Kensington and Chelsea 1344539
# 2018 Kensington and Chelsea 1363880
# 2019 Kensington and Chelsea 1241422
# 2020 Kensington and Chelsea 1325101

# %%
# Make a table of year, borough which has second maximum average price and how much for every year 
properties_without_Kensington_and_Chelsa = properties6.drop(['Kensington and Chelsea'], axis = 1)
for year1 in properties_without_Kensington_and_Chelsa.index:
    y = pd.Series(properties_without_Kensington_and_Chelsa.loc[year1, :])
    maximum_avg_price = y.max()
    print(year1, y.idxmax(),  maximum_avg_price)
# Out:
# 1995 Westminster 133689
# 1996 Westminster 139188
# 1997 Westminster 165447
# 1998 Westminster 190531
# 1999 Westminster 214042
# 2000 Westminster 260492
# 2001 Westminster 296105
# 2002 Westminster 339622
# 2003 Westminster 363466
# 2004 Westminster 379395
# 2005 Westminster 399384
# 2006 Westminster 436864
# 2007 Westminster 514426
# 2008 Westminster 540196
# 2009 Westminster 532096
# 2010 Westminster 606698
# 2011 Westminster 632513
# 2012 Westminster 696926
# 2013 Westminster 789972
# 2014 Westminster 922702
# 2015 Westminster 964643
# 2016 Westminster 995543
# 2017 Westminster 1064771
# 2018 Westminster 1020025
# 2019 Westminster 955998
# 2020 Westminster 965048

# %%
# Make a table of year, borough which has third maximum average price and how much for every year 
properties_without_KensingtonAndChelsa_and_Westminster = properties6.drop(['Kensington and Chelsea', 'Westminster'], axis = 1)
for year1 in properties_without_KensingtonAndChelsa_and_Westminster.index:
    z = pd.Series(properties_without_KensingtonAndChelsa_and_Westminster.loc[year1, :])
    maximum_avg_price = z.max()
    print(year1, z.idxmax(),  maximum_avg_price)
# Out:
# 1995 Hammersmith and Fulham 123238
# 1996 Camden 133810
# 1997 Hammersmith and Fulham 151723
# 1998 Hammersmith and Fulham 175340
# 1999 Hammersmith and Fulham 198901
# 2000 Hammersmith and Fulham 247266
# 2001 Camden 278594
# 2002 Camden 314179
# 2003 Camden 323053
# 2004 Camden 351847
# 2005 Camden 368345
# 2006 Hammersmith and Fulham 397586
# 2007 Hammersmith and Fulham 474140
# 2008 Camden 501223
# 2009 Camden 454628
# 2010 Camden 513221
# 2011 Camden 554392
# 2012 Camden 586165
# 2013 Camden 667447
# 2014 Camden 756486
# 2015 Camden 787440
# 2016 Camden 807118
# 2017 Camden 839347
# 2018 Camden 842410
# 2019 Camden 843066
# 2020 Camden 832577

# %% [markdown]
# ### 4. Conclusion
# What can you conclude? Type out your conclusion below.
#
# Look back at your notebook. Think about how you might summarize what you have done, and prepare a quick presentation on it to your mentor at your next meeting.
#
# We hope you enjoyed this practical project. It should have consolidated your data hygiene and pandas skills by looking at a real-world problem involving just the kind of dataset you might encounter as a budding data scientist. Congratulations, and looking forward to seeing you at the next step in the course!

# %% [markdown]
# * From the analysis of the provided dataset, it can be concluded that 'Kensington and Chelsea' borough was the most expensive borough in those years 1995-2020. The maximum price change between two consecutive year is 132730.0 euros. The range of change (avg) is 278091.0 euros.
# * Westminster the 2nd most expensive whereas "Hammersmith and Fulham" and "Camden" were the 3rd expensive boroughs.
# * The maximum housing price ratio between the year 2018 to 1998 was for borough "Hackney", with a value of 6.2
